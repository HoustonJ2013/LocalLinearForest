# %%
import numpy as np
import matplotlib.pylab as plt
# %matplotlib inline
f = lambda x: np.log(1 + np.exp(6 * x)) + np.random.normal(0, 20, len(x))
f0 = lambda x: np.log(1 + np.exp(6 * x))

# %%
x = np.arange(-1, 1, 0.01)
y = f(x)
plt.plot(x, y, "r.")
